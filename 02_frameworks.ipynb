# %% [markdown]
# ## Wrappers. Frameworks. W&B Experiments Monitoring.

# %% [markdown]
# ## 1. Wrappers
#
# ### Reward Wrapper
# Мы знаем, что окружения создаются с помощью команды ``gym.make(<имя среды>)``, но что если мы хотим немного изменить окружение или добавить какой-то дополнительный функционал? Для этого существуют обертки (wrappers). Вспомним среду ``Taxi-v3``, предположим, что мы хотим поменять вознаграждения на следующие: 1 за решение задачи, -1 за неправильную посадку/высадку пассажира и 0 во всех остальных случаях. Для этого мы можем воспользоваться ``RewardWrapper``-ом:

# %%
import gym

try:
    import colab
    COLAB = True
except ModuleNotFoundError:
    COLAB = False
    pass

# %%
gym.__version__
# Out:
# '0.17.3'

# %%
class MyRewardWrapper(gym.RewardWrapper):
    def reward(self, reward):
        if reward == -1:
            return 0
        elif reward == 20:
            return 1
        elif reward == -10:
            return -1
        else: 
            raise KeyError

# %%
env = gym.make("Taxi-v3")
env = MyRewardWrapper(env)
observation = env.reset()

rewards = set()

while True:
    observation, reward, done, info = env.step(env.action_space.sample())
    rewards.add(reward)
    if done:
        break

# выведем все вознаграждения, которые получал агент
print(rewards)
env.close()
# Out:
# {0, -1}

# %% [markdown]
# ### Time Limit Wrapper
#
# В зависимости от рандома, мы могли получить разные результаты, но обычно это ``{0, -1}. Откуда такой результат? Ведь среда заканчивается только когда задание выполнено. Все дело во встроенной обертке ограничивающей максимальное количество шагов.

# %%
env = gym.make("Taxi-v3")
print(type(env))
env.close()
# Out:
# <class 'gym.wrappers.time_limit.TimeLimit'>

# %%
MyRewardWrapper(env)
# Out:
# <MyRewardWrapper<TimeLimit<TaxiEnv<Taxi-v3>>>>

# %% [markdown]
# Можно воспользоваться окружением без этой обертки, вызвав ``.env``:

# %%
env = gym.make("Taxi-v3").env
env = MyRewardWrapper(env)

observation = env.reset()
rewards = set()

while True:
    observation, reward, done, info = env.step(env.action_space.sample())
    rewards.add(reward)
    if done:
        break

print(rewards)
env.close()
# Out:
# {0, 1, -1}

# %% [markdown]
# А если у нас есть окружение без этого враппера по умолчанию, то можно добавить его вот так:

# %%
env = gym.make("Taxi-v3").env
env = MyRewardWrapper(env)
env = gym.wrappers.TimeLimit(env, max_episode_steps=1)

observation = env.reset()
rewards = set()

while True:
    observation, reward, done, info = env.step(env.action_space.sample())
    rewards.add(reward)
    print(observation)
    if done:
        break

print(rewards)
env.close()
# Out:
# 143
# {0}

# %% [markdown]
# Как вы считаете, корректно ли с точки зрения MDP, если окружения будет досрочно возвращать ``done=True``? Чтобы различать два случая завершения среды, в ``info`` передается дополнительный ключ ``TimeLimit.truncated: True``, если среду завершил ``TimeLimit`` враппер:

# %%
env = gym.make("Taxi-v3")
env = gym.wrappers.TimeLimit(env, max_episode_steps=1)

env.reset()
_, _, done, info = env.step(env.action_space.sample())
print(f"done: {done}")
print(f"info: {info}")
env.close()
# Out:
# done: True
# info: {'prob': 1.0, 'TimeLimit.truncated': True}

# %% [markdown]
# ### Action Wrapper
# Представим, что наш водитель находится не в лучшем своем состоянии и независимо от выбора агента, в 50% случаев совершает случайные действий. Сделать среду стохастическои и добиться такого эффекта мы можем, используя ``ActionWrapper``:

# %%
import numpy as np

class TaxiRandomActionWrapper(gym.ActionWrapper):

    def __init__(self, env, probability=0.5):
        super().__init__(env) 
        self.probability = probability
        

    def action(self, action):
        if np.random.random() < self.probability:
            return env.action_space.sample()
        else: 
            return action

# %% [markdown]
# Чтобы проверить, что обертка работает будем выполнять единственное действие:

# %%
env = gym.make("Taxi-v3").env
env = MyRewardWrapper(env)
env = TaxiRandomActionWrapper(env)

observation = env.reset()
rewards = set()
done = True
while done:
    action = 0
    observation, reward, done, info = env.step(action)
    rewards.add(reward)
    if done:
        break

print(rewards)
env.close()
# Out:
# {0}

# %% [markdown]
# ### Wrapper
#
# Класс ``gym.Wrapper`` является базовым для всех оберток. Подкласс может переопределить    многие методы для изменения поведения исходной среды, не изменяя при этом ее исходный код. Например, мы можем изменить метод step и добавить, какую-то дополнительную информацию в ``info``:

# %%
class MyWrapper(gym.Wrapper):
    
    def step(self, action):
        observation, reward, done, info = self.env.step(action)
        info['Wrapped'] = True
        return observation, reward, done, info

# %%
env = gym.make("Taxi-v3")
env = MyWrapper(env)

env.reset()
_, _, _, info = env.step(env.action_space.sample())

print(info)
env.close()
# Out:
# {'prob': 1.0, 'Wrapped': True}

# %% [markdown]
# ### Monitor
#
# Обертка ``Monitor``, позволяет сохранять часть эпизодов в видеоформате. Для ее работы в колабе нам придется настроить виртуальный дисплей.

# %%
if COLAB:
    # !wget https://gist.githubusercontent.com/Tviskaron/4d35eabce2e057dd2ea49a00b00aaa41/raw/f1e25fc6ac6d8f11cb585559ce8b2ab9ffefd67b/colab_render.sh -O colab_render.sh -q
    # !sh colab_render.sh
    # !wget https://gist.githubusercontent.com/Tviskaron/d91decc1ca5f1b09af2f9f080011a925/raw/0d3474f65b4aea533996ee00edf99a37e4da5561/colab_render.py -O colab_render.py -q 

    import colab_render
# Out:
#      |████████████████████████████████| 448 kB 33.8 MB/s
# Selecting previously unselected package python-opengl.
# (Reading database ... 155632 files and directories currently installed.)
# Preparing to unpack .../python-opengl_3.1.0+dfsg-1_all.deb ...
# Unpacking python-opengl (3.1.0+dfsg-1) ...
# Setting up python-opengl (3.1.0+dfsg-1) ...
# Selecting previously unselected package xvfb.
# (Reading database ... 157987 files and directories currently installed.)
# Preparing to unpack .../xvfb_2%3a1.19.6-1ubuntu4.10_amd64.deb ...
# Unpacking xvfb (2:1.19.6-1ubuntu4.10) ...
# Setting up xvfb (2:1.19.6-1ubuntu4.10) ...
# Processing triggers for man-db (2.8.3-2ubuntu0.1) ...
#      |████████████████████████████████| 67 kB 5.8 MB/s

# %%
# библиотеки и функции, которые потребуеются показа видео

import glob
import io
import base64
from IPython import display as ipythondisplay
from IPython.display import HTML
from gym.envs.classic_control import rendering
import matplotlib.pyplot as plt

# %matplotlib inline


org_constructor = rendering.Viewer.__init__


def constructor(self, *args, **kwargs):
    org_constructor(self, *args, **kwargs)
    self.window.set_visible(visible=False)


rendering.Viewer.__init__ = constructor


def show_video(folder="./video"):
    mp4list = glob.glob(folder + '/*.mp4')
    if len(mp4list) > 0:
        mp4 = sorted(mp4list, key=lambda x: x[-15:], reverse=True)[0]
        video = io.open(mp4, 'r+b').read()
        encoded = base64.b64encode(video)
        ipythondisplay.display(HTML(data='''<video alt="test" autoplay 
                loop controls style="height: 400px;">
                <source src="data:video/mp4;base64,{0}" type="video/mp4" />
             </video>'''.format(encoded.decode('ascii'))))
    else:
        print("Could not find video")

# %%
if COLAB:
  # !wget http://www.atarimania.com/roms/Roms.rar
  # !mkdir /content/ROM/
  # !unrar e /content/Roms.rar /content/ROM/
  # !python -m atari_py.import_roms /content/ROM/
# Out:
# --2022-06-06 17:55:20--  http://www.atarimania.com/roms/Roms.rar
# Resolving www.atarimania.com (www.atarimania.com)... 195.154.81.199
# Connecting to www.atarimania.com (www.atarimania.com)|195.154.81.199|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 19583716 (19M) [application/x-rar-compressed]
# Saving to: ‘Roms.rar’
#
# Roms.rar            100%[===================>]  18.68M   820KB/s    in 24s
#
# 2022-06-06 17:55:45 (798 KB/s) - ‘Roms.rar’ saved [19583716/19583716]
#
#
# UNRAR 5.50 freeware      Copyright (c) 1993-2017 Alexander Roshal
#
#
# Extracting from /content/Roms.rar
#
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#
# Would you like to replace the existing file /content/ROM/208 in 1 Game Select ROM (PAL).bin
#   2048 bytes, modified on 2008-06-28 10:32
# with a new one
#   2048 bytes, modified on 2008-06-28 10:32
#
# [Y]es, [N]o, [A]ll, n[E]ver, [R]ename, [Q]uit A
#
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
# All OK
# copying kangaroo.bin from /content/ROM/Kangaroo (1983) (Atari - GCC, Kevin Osborn) (CX2689) ~.bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/kangaroo.bin
# copying surround.bin from /content/ROM/Surround (32 in 1) (Bit Corporation) (R320).bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/surround.bin
# copying bowling.bin from /content/ROM/Bowling.bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/bowling.bin
# copying gopher.bin from /content/ROM/Gopher (Gopher Attack) (1982) (U.S. Games Corporation - JWDA, Sylvia Day, Todd Marshall, Robin McDaniel, Henry Will IV) (VC2001) ~.bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/gopher.bin
# copying riverraid.bin from /content/ROM/River Raid.bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/riverraid.bin
# copying wizard_of_wor.bin from /content/ROM/Wizard of Wor.bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/wizard_of_wor.bin
# copying robotank.bin from /content/ROM/Robot Tank.bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/robotank.bin
# copying enduro.bin from /content/ROM/Enduro.bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/enduro.bin
# copying pacman.bin from /content/ROM/Pac-Man (1982) (Atari, Tod Frye) (CX2646) (PAL).bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/pacman.bin
# copying seaquest.bin from /content/ROM/Seaquest (1983) (Activision, Steve Cartwright) (AX-022) ~.bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/seaquest.bin
# copying koolaid.bin from /content/ROM/Kool-Aid Man (Kool Aid Pitcher Man) (1983) (M Network, Stephen Tatsumi, Jane Terjung - Kool Aid) (MT4648) ~.bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/koolaid.bin
# copying jamesbond.bin from /content/ROM/James Bond 007 (James Bond Agent 007) (1984) (Parker Brothers - On-Time Software, Joe Gaucher, Dan Kurczewski, Louis Marbel, Kathy Von) (PB5110) ~.bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/jamesbond.bin
# copying double_dunk.bin from /content/ROM/Double Dunk (Super Basketball) (1989) (Atari, Matthew L. Hubbard) (CX26159) ~.bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/double_dunk.bin
# copying pooyan.bin from /content/ROM/Pooyan.bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/pooyan.bin
# copying alien.bin from /content/ROM/Alien (1982) (20th Century Fox Video Games, Douglas 'Dallas North' Neubauer) (11006) ~.bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/alien.bin
# copying phoenix.bin from /content/ROM/Phoenix.bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/phoenix.bin
# copying galaxian.bin from /content/ROM/Galaxian (1983) (Atari - GCC, Mark Ackerman, Tom Calderwood, Glenn Parker) (CX2684) ~.bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/galaxian.bin
# copying asteroids.bin from /content/ROM/Asteroids [no copyright].bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/asteroids.bin
# copying solaris.bin from /content/ROM/Solaris.bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/solaris.bin
# copying ms_pacman.bin from /content/ROM/Ms. Pac-Man (1983) (Atari - GCC, Mark Ackerman, Glenn Parker) (CX2675) ~.bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/ms_pacman.bin
# copying hero.bin from /content/ROM/H.E.R.O..bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/hero.bin
# copying skiing.bin from /content/ROM/Skiing.bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/skiing.bin
# copying tutankham.bin from /content/ROM/Tutankham (1983) (Parker Brothers, Dave Engman, Dawn Stockbridge) (PB5340) ~.bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/tutankham.bin
# copying space_invaders.bin from /content/ROM/Space Invaders (1980) (Atari, Richard Maurer - Sears) (CX2632 - 49-75153) ~.bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/space_invaders.bin
# copying frostbite.bin from /content/ROM/Frostbite (Iceman) (1983) (Activision, Steve Cartwright) (AX-031) ~.bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/frostbite.bin
# copying trondead.bin from /content/ROM/TRON - Deadly Discs (TRON Joystick) (1983) (M Network - INTV - APh Technological Consulting, Jeff Ronne, Brett Stutz) (MT5662) ~.bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/trondead.bin
# copying kaboom.bin from /content/ROM/Kaboom! (Paddle) (1981) (Activision, Larry Kaplan, David Crane) (AG-010, CAG-010, AG-010-04) ~.bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/kaboom.bin
# copying journey_escape.bin from /content/ROM/Journey Escape.bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/journey_escape.bin
# copying gravitar.bin from /content/ROM/Gravitar (1983) (Atari, Dan Hitchens, Mimi Nyden) (CX2685) ~.bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/gravitar.bin
# copying lost_luggage.bin from /content/ROM/Lost Luggage (Airport Mayhem) (1982) (Apollo - Games by Apollo, Larry Minor, Ernie Runyon, Ed Salvo) (AP-2004) [no opening scene] ~.bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/lost_luggage.bin
# copying air_raid.bin from /content/ROM/Air Raid (PAL).bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/air_raid.bin
# copying pitfall.bin from /content/ROM/Pitfall! - Pitfall Harry's Jungle Adventure (Jungle Runner) (1982) (Activision, David Crane) (AX-018, AX-018-04) ~.bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/pitfall.bin
# copying road_runner.bin from patched version of /content/ROM/Road Runner (1989) (Atari - Bobco, Robert C. Polaro) (CX2663) ~.bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/road_runner.bin
# copying laser_gates.bin from /content/ROM/Laser Gates (AKA Innerspace) (1983) (Imagic, Dan Oliver) (720118-2A, 13208, EIX-007-04I) (PAL).bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/laser_gates.bin
# copying adventure.bin from /content/ROM/Adventure (PAL).bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/adventure.bin
# copying demon_attack.bin from /content/ROM/Demon Attack.bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/demon_attack.bin
# copying chopper_command.bin from /content/ROM/Chopper Command (1982) (Activision, Bob Whitehead) (AX-015, AX-015-04) ~.bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/chopper_command.bin
# copying carnival.bin from /content/ROM/Carnival.bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/carnival.bin
# copying elevator_action.bin from /content/ROM/Elevator Action (Prototype).bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/elevator_action.bin
# copying defender.bin from /content/ROM/Defender (1982) (Atari, Robert C. Polaro, Alan J. Murphy - Sears) (CX2609 - 49-75186) ~.bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/defender.bin
# copying atlantis.bin from /content/ROM/Atlantis (Lost City of Atlantis) (1982) (Imagic, Dennis Koble) (720103-1A, 720103-1B, IA3203, IX-010-04) ~.bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/atlantis.bin
# copying sir_lancelot.bin from /content/ROM/Sir Lancelot (1983) (Xonox - K-Tel Software - Product Guild, Anthony R. Henderson) (99006, 6220) (PAL).bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/sir_lancelot.bin
# copying qbert.bin from /content/ROM/Q-bert (1987) (Atari) (CX26150).bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/qbert.bin
# copying video_pinball.bin from /content/ROM/Video Pinball - Arcade Pinball (1981) (Atari, Bob Smith - Sears) (CX2648 - 49-75161) ~.bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/video_pinball.bin
# copying beam_rider.bin from /content/ROM/Beamrider (1984) (Activision - Cheshire Engineering, David Rolfe, Larry Zwick) (AZ-037-04) ~.bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/beam_rider.bin
# copying king_kong.bin from /content/ROM/King Kong (1982) (Tigervision - Software Electronics Corporation, Karl T. Olinger - Teldec) (7-001 - 3.60001 VE) (PAL).bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/king_kong.bin
# copying amidar.bin from /content/ROM/Amidar (1982) (Parker Brothers, Ed Temple) (PB5310) ~.bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/amidar.bin
# copying venture.bin from /content/ROM/Venture.bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/venture.bin
# copying private_eye.bin from /content/ROM/Private Eye.bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/private_eye.bin
# copying time_pilot.bin from /content/ROM/Time Pilot (1983) (Coleco - Woodside Design Associates, Harley H. Puthuff Jr.) (2663) ~.bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/time_pilot.bin
# copying name_this_game.bin from /content/ROM/Name This Game (Guardians of Treasure, Octopussy) (1983) (U.S. Games Corporation - JWDA, Roger Booth, Sylvia Day, Ron Dubren, Todd Marshall, Robin McDaniel, Wes Trager, Henry Will IV) (VC1007) ~.bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/name_this_game.bin
# copying montezuma_revenge.bin from /content/ROM/Montezuma's Revenge - Featuring Panama Joe.bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/montezuma_revenge.bin
# copying zaxxon.bin from /content/ROM/Zaxxon.bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/zaxxon.bin
# copying freeway.bin from /content/ROM/Freeway (1981) (Activision, David Crane) (AG-009, AG-009-04) ~.bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/freeway.bin
# copying kung_fu_master.bin from /content/ROM/Kung-Fu Master.bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/kung_fu_master.bin
# copying mr_do.bin from /content/ROM/Mr. Do! (PAL).bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/mr_do.bin
# copying yars_revenge.bin from /content/ROM/Yars' Revenge.bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/yars_revenge.bin
# copying breakout.bin from /content/ROM/Breakout - Breakaway IV (Paddle) (1978) (Atari, Brad Stewart - Sears) (CX2622 - 6-99813, 49-75107) ~.bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/breakout.bin
# copying crazy_climber.bin from /content/ROM/Crazy Climber (1983) (Atari - Roklan, Joe Gaucher, Alex Leavens) (CX2683) ~.bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/crazy_climber.bin
# copying battle_zone.bin from /content/ROM/Battlezone.bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/battle_zone.bin
# copying boxing.bin from /content/ROM/Boxing - La Boxe (1980) (Activision, Bob Whitehead) (AG-002, CAG-002, AG-002-04) ~.bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/boxing.bin
# copying tennis.bin from /content/ROM/Tennis - Le Tennis (1981) (Activision, Alan Miller) (AG-007, CAG-007) ~.bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/tennis.bin
# copying ice_hockey.bin from /content/ROM/Ice Hockey - Le Hockey Sur Glace (1981) (Activision, Alan Miller) (AX-012, CAX-012, AX-012-04) ~.bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/ice_hockey.bin
# copying fishing_derby.bin from /content/ROM/Fishing Derby.bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/fishing_derby.bin
# copying frogger.bin from /content/ROM/Frogger (1982) (Parker Brothers, Ed English, David Lamkins) (PB5300) ~.bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/frogger.bin
# copying star_gunner.bin from /content/ROM/Stargunner (1983) (Telesys, Alex Leavens) (1005) ~.bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/star_gunner.bin
# copying keystone_kapers.bin from /content/ROM/Keystone Kapers - Raueber und Gendarm (1983) (Activision, Garry Kitchen - Ariola) (EAX-025, EAX-025-04I - 711 025-725) (PAL).bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/keystone_kapers.bin
# copying pong.bin from /content/ROM/Video Olympics - Pong Sports.bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/pong.bin
# copying krull.bin from /content/ROM/Krull.bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/krull.bin
# copying asterix.bin from /content/ROM/Asterix (AKA Taz) (1984) (Atari, Jerome Domurat, Steve Woita) (CX2696).bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/asterix.bin
# copying assault.bin from /content/ROM/Assault (AKA Sky Alien) (1983) (Bomb - Onbase) (CA281).bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/assault.bin
# copying centipede.bin from /content/ROM/Centipede (1983) (Atari - GCC) (CX2676) ~.bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/centipede.bin
# copying up_n_down.bin from /content/ROM/Up 'n Down (1984) (SEGA - Beck-Tech, Steve Beck, Phat Ho) (009-01) ~.bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/up_n_down.bin
# copying donkey_kong.bin from /content/ROM/Donkey Kong (1982) (Coleco - Woodside Design Associates - Imaginative Systems Software, Garry Kitchen) (2451) ~.bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/donkey_kong.bin
# copying berzerk.bin from /content/ROM/Berzerk (1982) (Atari, Dan Hitchens - Sears) (CX2650 - 49-75168) ~.bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/berzerk.bin
# copying bank_heist.bin from /content/ROM/Bank Heist (Bonnie & Clyde, Cops 'n' Robbers, Hold-Up, Roaring 20's) (1983) (20th Century Fox Video Games, Bill Aspromonte) (11012) ~.bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/bank_heist.bin

# %%
# !ls ./video
# Out:
# openaigym.episode_batch.0.71.stats.json
# openaigym.manifest.0.71.manifest.json
# openaigym.video.0.71.video000000.meta.json
# openaigym.video.0.71.video000000.mp4

# %%
env = gym.make("Breakout-v0")
env = gym.wrappers.Monitor(env, directory="./video", force=True)
# video_callable (Optional[function, False]): function that takes in the index of 
# the episode and outputs a boolean, indicating whether we should record a video on this episode. 
# The default (for video_callable is None) is to take perfect cubes, capped at 1000. 
# False disables video recording.
           
env.reset()

while True:
    observation, reward, done, info = env.step(env.action_space.sample())
    if done:
        break

env.close()
show_video()
# Out:
# <video alt="test" autoplay
#                 loop controls style="height: 400px;">
#                 <source src="data:video/mp4;base64,..." type="video/mp4" />
#              </video>

# %%
# def capped_cubic_video_schedule(episode_id):
#   if episode_id < 1000:
#        return int(round(episode_id ** (1. / 3))) ** 3 == episode_id
#    else:
#        return episode_id % 1000 == 0

# %% [markdown]
# ### Atari Preprocessing
#
#
# Предварительная обработка для Atari 2600.
# Класс ``AtariPreprocessing`` следует рекомендациям статьи: Revisiting the Arcade Learning Environment: Evaluation Protocols and Open Problems for General Agents" Machado et al. (2018).

# %%
env = gym.make("BoxingNoFrameskip-v0")

print(f'Original: {env.observation_space}')
# Out:
# Original: Box(0, 255, (210, 160, 3), uint8)

# %%
env = gym.wrappers.AtariPreprocessing(gym.make("BoxingNoFrameskip-v0"))

print(f'Preprocessed: {env.observation_space}')
# Out:
# Preprocessed: Box(0, 255, (84, 84), uint8)

# %% [markdown]
# ## 2. RL Frameworks
#
# Переиспользование написанного кода является хорошей практикой написания программ и обучение с подкреплением не является исключением. Существует большое число готовых реализаций RL алгоритмов. Рассмотрим некоторые из них:

# %% [markdown]
# ### OpenAI Baselines
#
#
#
# <img src="https://github.com/openai/baselines/raw/master/data/logo.jpg" alt="Drawing" style="width: 200px;"/>
#
# Цитата из [репозитория](https://github.com/openai/baselines):
#
# «OpenAI Baselines is a set of high-quality implementations of reinforcement learning algorithms.
#
# These algorithms will make it easier for the research community to replicate, refine, and identify new ideas, and will create good baselines to build research on top of. Our DQN implementation and its variants are roughly on par with the scores in published papers. We expect they will be used as a base around which new ideas can be added, and as a tool for comparing a new approach against existing ones.»
#
# **Neural Network Framework:** Tensorflow 1.x
#
# **Список алгоритмов:** A2C, ACER, ACKTR, DDPG, DQN, GAIL, HER, PPO, TRPO
#
# Пример использования алгоритма DQN (без запуска, т.к. нужен tf1, а версия baselines с поддержкой tf2 еще в процессе):
# ```python
# import gym
# from baselines import deepq
#
#
# def main():
#     env = gym.make("PongNoFrameskip-v4")
#     env = deepq.wrap_atari_dqn(env)
#     model = deepq.learn(
#         env,
#         "conv_only",
#         convs=[(32, 8, 4), (64, 4, 2), (64, 3, 1)],
#         hiddens=[256],
#         dueling=True,
#         total_timesteps=0
#     )
#
#     while True:
#         obs, done = env.reset(), False
#         episode_rew = 0
#         while not done:
#             env.render()
#             obs, rew, done, _ = env.step(model(obs[None])[0])
#             episode_rew += rew
#         print("Episode reward", episode_rew)
#
#
# if __name__ == '__main__':
#     main()
# ```
#
# Установка для colab и примеры визуализации: [baselines_viz.ipynb](https://colab.research.google.com/github/openai/baselines/blob/master/docs/viz/viz.ipynb).

# %%
import numpy as np

q = np.array([1, 2])
q[None]
# Out:
# array([[1, 2]])

# %% [markdown]
# ### Stable Baselines
#
# <img src="https://miro.medium.com/max/1890/1*Qykf3HYCbSxw-nDYdLSbeQ.png" alt="Drawing" style="width: 500px;"/>
#
#
# [Stable Baselines](https://github.com/hill-a/stable-baselines) $-$ это набор улучшенных реализаций алгоритмов обучения с подкреплением, основанный на OpenAI Baselines.
#
# **Neural Network Framework:** Tensorflow 1.x
#
# **Список алгоритмов:**  A2C, ACER, ACKTR, DDPG, DQN, GAIL, HER, **SAC**, **TD3**, PPO, TRPO
#
# Запуск алгоритма PPO (Proximal Policy Optimization):
# ```python
# # from https://github.com/hill-a/stable-baselines
# import gym
#
# from stable_baselines.common.policies import MlpPolicy
# from stable_baselines import PPO2
#
# env = gym.make('CartPole-v0')
#
# model = PPO2(MlpPolicy, env, verbose=1)
# # Train the agent
# model.learn(total_timesteps=10000)
#
# # Enjoy trained agent
# obs = env.reset()
# for i in range(1000):
#     action, _states = model.predict(obs, deterministic=False)
#     obs, reward, done, info = env.step(action)
#     env.render()
#     if done:
#         obs = env.reset()
# env.close()
# ```
#
# Подробная статья о данном фреймворке: [stable-baselines-a-fork-of-openai-baselines-reinforcement)](https://towardsdatascience.com/stable-baselines-a-fork-of-openai-baselines-reinforcement-learning-made-easy-df87c4b2fc82)

# %% [markdown]
# ### Stable Baselines3
#
#
# Stable Baselines3 $-$ это версия Stable Baselines на PyTorch.
#
# **Neural Network Framework:** PyTorch.
#
# **Список алгоритмов:** A2C, DDPG, DQN, HER, PPO, SAC, TD3
#
# Tutorial: [Stable Baselines3 Tutorial](https://github.com/araffin/rl-tutorial-jnrr19)

# %%
if COLAB:
    # !pip install stable-baselines3[extra] --quiet
# Out:
#      |████████████████████████████████| 177 kB 29.0 MB/s
#      |████████████████████████████████| 1.5 MB 61.1 MB/s
#      |████████████████████████████████| 1.6 MB 60.2 MB/s
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
#   Building wheel for gym (setup.py) ... done
#   Building wheel for AutoROM.accept-rom-license (PEP 517) ... done

# %%
import gym
from stable_baselines3 import DQN

env = gym.wrappers.Monitor(gym.make('CartPole-v0'), directory='./video', force=True)
model = DQN('MlpPolicy', env, verbose=1, learning_starts=2000).learn(50000)
env.close()

show_video()
# Out:
# Streaming output truncated to the last 5000 lines.
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0573   |
# |    n_updates        | 4746     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.4     |
# |    ep_rew_mean      | 10.4     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1892     |
# |    fps              | 701      |
# |    time_elapsed     | 29       |
# |    total_timesteps  | 21029    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.117    |
# |    n_updates        | 4757     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.5     |
# |    ep_rew_mean      | 10.5     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1896     |
# |    fps              | 701      |
# |    time_elapsed     | 30       |
# |    total_timesteps  | 21074    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0531   |
# |    n_updates        | 4768     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.5     |
# |    ep_rew_mean      | 10.5     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1900     |
# |    fps              | 701      |
# |    time_elapsed     | 30       |
# |    total_timesteps  | 21117    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0433   |
# |    n_updates        | 4779     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.4     |
# |    ep_rew_mean      | 10.4     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1904     |
# |    fps              | 701      |
# |    time_elapsed     | 30       |
# |    total_timesteps  | 21158    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0504   |
# |    n_updates        | 4789     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.5     |
# |    ep_rew_mean      | 10.5     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1908     |
# |    fps              | 702      |
# |    time_elapsed     | 30       |
# |    total_timesteps  | 21199    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.109    |
# |    n_updates        | 4799     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.5     |
# |    ep_rew_mean      | 10.5     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1912     |
# |    fps              | 702      |
# |    time_elapsed     | 30       |
# |    total_timesteps  | 21240    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0517   |
# |    n_updates        | 4809     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.6     |
# |    ep_rew_mean      | 10.6     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1916     |
# |    fps              | 702      |
# |    time_elapsed     | 30       |
# |    total_timesteps  | 21287    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.115    |
# |    n_updates        | 4821     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.7     |
# |    ep_rew_mean      | 10.7     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1920     |
# |    fps              | 702      |
# |    time_elapsed     | 30       |
# |    total_timesteps  | 21333    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0366   |
# |    n_updates        | 4833     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.6     |
# |    ep_rew_mean      | 10.6     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1924     |
# |    fps              | 702      |
# |    time_elapsed     | 30       |
# |    total_timesteps  | 21369    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0367   |
# |    n_updates        | 4842     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.6     |
# |    ep_rew_mean      | 10.6     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1928     |
# |    fps              | 702      |
# |    time_elapsed     | 30       |
# |    total_timesteps  | 21413    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0373   |
# |    n_updates        | 4853     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.6     |
# |    ep_rew_mean      | 10.6     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1932     |
# |    fps              | 702      |
# |    time_elapsed     | 30       |
# |    total_timesteps  | 21458    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0199   |
# |    n_updates        | 4864     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.6     |
# |    ep_rew_mean      | 10.6     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1936     |
# |    fps              | 702      |
# |    time_elapsed     | 30       |
# |    total_timesteps  | 21498    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0429   |
# |    n_updates        | 4874     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.7     |
# |    ep_rew_mean      | 10.7     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1940     |
# |    fps              | 702      |
# |    time_elapsed     | 30       |
# |    total_timesteps  | 21543    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0402   |
# |    n_updates        | 4885     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.7     |
# |    ep_rew_mean      | 10.7     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1944     |
# |    fps              | 702      |
# |    time_elapsed     | 30       |
# |    total_timesteps  | 21586    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0678   |
# |    n_updates        | 4896     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.6     |
# |    ep_rew_mean      | 10.6     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1948     |
# |    fps              | 703      |
# |    time_elapsed     | 30       |
# |    total_timesteps  | 21627    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0898   |
# |    n_updates        | 4906     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.7     |
# |    ep_rew_mean      | 10.7     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1952     |
# |    fps              | 703      |
# |    time_elapsed     | 30       |
# |    total_timesteps  | 21673    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.035    |
# |    n_updates        | 4918     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.8     |
# |    ep_rew_mean      | 10.8     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1956     |
# |    fps              | 703      |
# |    time_elapsed     | 30       |
# |    total_timesteps  | 21733    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.106    |
# |    n_updates        | 4933     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11       |
# |    ep_rew_mean      | 11       |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1960     |
# |    fps              | 703      |
# |    time_elapsed     | 30       |
# |    total_timesteps  | 21796    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0438   |
# |    n_updates        | 4948     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.1     |
# |    ep_rew_mean      | 11.1     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1964     |
# |    fps              | 703      |
# |    time_elapsed     | 31       |
# |    total_timesteps  | 21842    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0512   |
# |    n_updates        | 4960     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.1     |
# |    ep_rew_mean      | 11.1     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1968     |
# |    fps              | 703      |
# |    time_elapsed     | 31       |
# |    total_timesteps  | 21884    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0836   |
# |    n_updates        | 4970     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.1     |
# |    ep_rew_mean      | 11.1     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1972     |
# |    fps              | 703      |
# |    time_elapsed     | 31       |
# |    total_timesteps  | 21928    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0211   |
# |    n_updates        | 4981     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.1     |
# |    ep_rew_mean      | 11.1     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1976     |
# |    fps              | 703      |
# |    time_elapsed     | 31       |
# |    total_timesteps  | 21970    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0231   |
# |    n_updates        | 4992     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.1     |
# |    ep_rew_mean      | 11.1     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1980     |
# |    fps              | 703      |
# |    time_elapsed     | 31       |
# |    total_timesteps  | 22013    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0548   |
# |    n_updates        | 5003     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.1     |
# |    ep_rew_mean      | 11.1     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1984     |
# |    fps              | 704      |
# |    time_elapsed     | 31       |
# |    total_timesteps  | 22057    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0569   |
# |    n_updates        | 5014     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.2     |
# |    ep_rew_mean      | 11.2     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1988     |
# |    fps              | 704      |
# |    time_elapsed     | 31       |
# |    total_timesteps  | 22106    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0225   |
# |    n_updates        | 5026     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.4     |
# |    ep_rew_mean      | 11.4     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1992     |
# |    fps              | 704      |
# |    time_elapsed     | 31       |
# |    total_timesteps  | 22166    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.118    |
# |    n_updates        | 5041     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.4     |
# |    ep_rew_mean      | 11.4     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1996     |
# |    fps              | 704      |
# |    time_elapsed     | 31       |
# |    total_timesteps  | 22216    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0375   |
# |    n_updates        | 5053     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.4     |
# |    ep_rew_mean      | 11.4     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2000     |
# |    fps              | 700      |
# |    time_elapsed     | 31       |
# |    total_timesteps  | 22259    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0986   |
# |    n_updates        | 5064     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.5     |
# |    ep_rew_mean      | 11.5     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2004     |
# |    fps              | 697      |
# |    time_elapsed     | 31       |
# |    total_timesteps  | 22305    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0522   |
# |    n_updates        | 5076     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.5     |
# |    ep_rew_mean      | 11.5     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2008     |
# |    fps              | 697      |
# |    time_elapsed     | 32       |
# |    total_timesteps  | 22347    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0857   |
# |    n_updates        | 5086     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.5     |
# |    ep_rew_mean      | 11.5     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2012     |
# |    fps              | 697      |
# |    time_elapsed     | 32       |
# |    total_timesteps  | 22392    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0264   |
# |    n_updates        | 5097     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.5     |
# |    ep_rew_mean      | 11.5     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2016     |
# |    fps              | 698      |
# |    time_elapsed     | 32       |
# |    total_timesteps  | 22434    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0857   |
# |    n_updates        | 5108     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.4     |
# |    ep_rew_mean      | 11.4     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2020     |
# |    fps              | 698      |
# |    time_elapsed     | 32       |
# |    total_timesteps  | 22476    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0232   |
# |    n_updates        | 5118     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.5     |
# |    ep_rew_mean      | 11.5     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2024     |
# |    fps              | 698      |
# |    time_elapsed     | 32       |
# |    total_timesteps  | 22519    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0863   |
# |    n_updates        | 5129     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.5     |
# |    ep_rew_mean      | 11.5     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2028     |
# |    fps              | 698      |
# |    time_elapsed     | 32       |
# |    total_timesteps  | 22560    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0439   |
# |    n_updates        | 5139     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.4     |
# |    ep_rew_mean      | 11.4     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2032     |
# |    fps              | 698      |
# |    time_elapsed     | 32       |
# |    total_timesteps  | 22600    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0339   |
# |    n_updates        | 5149     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.4     |
# |    ep_rew_mean      | 11.4     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2036     |
# |    fps              | 698      |
# |    time_elapsed     | 32       |
# |    total_timesteps  | 22642    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0413   |
# |    n_updates        | 5160     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.4     |
# |    ep_rew_mean      | 11.4     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2040     |
# |    fps              | 698      |
# |    time_elapsed     | 32       |
# |    total_timesteps  | 22683    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0235   |
# |    n_updates        | 5170     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.4     |
# |    ep_rew_mean      | 11.4     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2044     |
# |    fps              | 698      |
# |    time_elapsed     | 32       |
# |    total_timesteps  | 22727    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0632   |
# |    n_updates        | 5181     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.5     |
# |    ep_rew_mean      | 11.5     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2048     |
# |    fps              | 698      |
# |    time_elapsed     | 32       |
# |    total_timesteps  | 22773    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0456   |
# |    n_updates        | 5193     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.6     |
# |    ep_rew_mean      | 11.6     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2052     |
# |    fps              | 699      |
# |    time_elapsed     | 32       |
# |    total_timesteps  | 
|
# |    time_elapsed     | 65       |
# |    total_timesteps  | 49385    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0853   |
# |    n_updates        | 11846    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 83.6     |
# |    ep_rew_mean      | 83.6     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 3220     |
# |    fps              | 749      |
# |    time_elapsed     | 66       |
# |    total_timesteps  | 49787    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.103    |
# |    n_updates        | 11946    |
# ----------------------------------
# <video alt="test" autoplay
#                 loop controls style="height: 400px;">
#                 <source src="data:video/mp4;base64,..." type="video/mp4" />
#              </video>

# %% [markdown]
# Изменим гиперпараметры и обучим с большим числом шагов:

# %%
from stable_baselines3.common.monitor import Monitor

env = gym.wrappers.Monitor(gym.make('CartPole-v0'), directory='./video', force=True)
env = Monitor(env, filename='./stable-baselines-logs')

policy_kwargs = dict(net_arch=[200, 200])


model = DQN(policy='MlpPolicy', env=env, verbose=1, 
            learning_starts=2000, policy_kwargs=policy_kwargs,
            target_update_interval=2000)

model.learn(80000)

env.close()
show_video()
# Out:
# Using cuda device
# Wrapping the env in a DummyVecEnv.
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 18.8     |
# |    ep_rew_mean      | 18.8     |
# |    exploration_rate | 0.991    |
# | time/               |          |
# |    episodes         | 4        |
# |    fps              | 100      |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 75       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 16.1     |
# |    ep_rew_mean      | 16.1     |
# |    exploration_rate | 0.985    |
# | time/               |          |
# |    episodes         | 8        |
# |    fps              | 137      |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 129      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 16.2     |
# |    ep_rew_mean      | 16.2     |
# |    exploration_rate | 0.977    |
# | time/               |          |
# |    episodes         | 12       |
# |    fps              | 173      |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 195      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 17.6     |
# |    ep_rew_mean      | 17.6     |
# |    exploration_rate | 0.967    |
# | time/               |          |
# |    episodes         | 16       |
# |    fps              | 246      |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 281      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 18.5     |
# |    ep_rew_mean      | 18.5     |
# |    exploration_rate | 0.956    |
# | time/               |          |
# |    episodes         | 20       |
# |    fps              | 321      |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 370      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 19.1     |
# |    ep_rew_mean      | 19.1     |
# |    exploration_rate | 0.946    |
# | time/               |          |
# |    episodes         | 24       |
# |    fps              | 393      |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 458      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 18.9     |
# |    ep_rew_mean      | 18.9     |
# |    exploration_rate | 0.937    |
# | time/               |          |
# |    episodes         | 28       |
# |    fps              | 365      |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 528      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 19.5     |
# |    ep_rew_mean      | 19.5     |
# |    exploration_rate | 0.926    |
# | time/               |          |
# |    episodes         | 32       |
# |    fps              | 426      |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 624      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 19.7     |
# |    ep_rew_mean      | 19.7     |
# |    exploration_rate | 0.916    |
# | time/               |          |
# |    episodes         | 36       |
# |    fps              | 481      |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 710      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 20.6     |
# |    ep_rew_mean      | 20.6     |
# |    exploration_rate | 0.902    |
# | time/               |          |
# |    episodes         | 40       |
# |    fps              | 552      |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 823      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 20.1     |
# |    ep_rew_mean      | 20.1     |
# |    exploration_rate | 0.895    |
# | time/               |          |
# |    episodes         | 44       |
# |    fps              | 590      |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 885      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 20       |
# |    ep_rew_mean      | 20       |
# |    exploration_rate | 0.886    |
# | time/               |          |
# |    episodes         | 48       |
# |    fps              | 634      |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 961      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 19.8     |
# |    ep_rew_mean      | 19.8     |
# |    exploration_rate | 0.878    |
# | time/               |          |
# |    episodes         | 52       |
# |    fps              | 675      |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 1031     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 20.4     |
# |    ep_rew_mean      | 20.4     |
# |    exploration_rate | 0.865    |
# | time/               |          |
# |    episodes         | 56       |
# |    fps              | 739      |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 1140     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 20.6     |
# |    ep_rew_mean      | 20.6     |
# |    exploration_rate | 0.853    |
# | time/               |          |
# |    episodes         | 60       |
# |    fps              | 794      |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 1235     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 20.3     |
# |    ep_rew_mean      | 20.3     |
# |    exploration_rate | 0.846    |
# | time/               |          |
# |    episodes         | 64       |
# |    fps              | 741      |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 1297     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 20       |
# |    ep_rew_mean      | 20       |
# |    exploration_rate | 0.838    |
# | time/               |          |
# |    episodes         | 68       |
# |    fps              | 715      |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 1360     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 19.8     |
# |    ep_rew_mean      | 19.8     |
# |    exploration_rate | 0.831    |
# | time/               |          |
# |    episodes         | 72       |
# |    fps              | 745      |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 1425     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 20.4     |
# |    ep_rew_mean      | 20.4     |
# |    exploration_rate | 0.816    |
# | time/               |          |
# |    episodes         | 76       |
# |    fps              | 805      |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 1551     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 20       |
# |    ep_rew_mean      | 20       |
# |    exploration_rate | 0.81     |
# | time/               |          |
# |    episodes         | 80       |
# |    fps              | 827      |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 1602     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 19.8     |
# |    ep_rew_mean      | 19.8     |
# |    exploration_rate | 0.803    |
# | time/               |          |
# |    episodes         | 84       |
# |    fps              | 852      |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 1659     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 19.6     |
# |    ep_rew_mean      | 19.6     |
# |    exploration_rate | 0.795    |
# | time/               |          |
# |    episodes         | 88       |
# |    fps              | 882      |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 1727     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 20       |
# |    ep_rew_mean      | 20       |
# |    exploration_rate | 0.781    |
# | time/               |          |
# |    episodes         | 92       |
# |    fps              | 934      |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 1842     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 20.4     |
# |    ep_rew_mean      | 20.4     |
# |    exploration_rate | 0.768    |
# | time/               |          |
# |    episodes         | 96       |
# |    fps              | 984      |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 1956     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 20.2     |
# |    ep_rew_mean      | 20.2     |
# |    exploration_rate | 0.76     |
# | time/               |          |
# |    episodes         | 100      |
# |    fps              | 999      |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 2017     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.495    |
# |    n_updates        | 4        |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 20.1     |
# |    ep_rew_mean      | 20.1     |
# |    exploration_rate | 0.753    |
# | time/               |          |
# |    episodes         | 104      |
# |    fps              | 1003     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 2082     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.381    |
# |    n_updates        | 20       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 20.3     |
# |    ep_rew_mean      | 20.3     |
# |    exploration_rate | 0.744    |
# | time/               |          |
# |    episodes         | 108      |
# |    fps              | 1005     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 2155     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.279    |
# |    n_updates        | 38       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 20.5     |
# |    ep_rew_mean      | 20.5     |
# |    exploration_rate | 0.733    |
# | time/               |          |
# |    episodes         | 112      |
# |    fps              | 1008     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 2249     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.121    |
# |    n_updates        | 62       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 20.2     |
# |    ep_rew_mean      | 20.2     |
# |    exploration_rate | 0.726    |
# | time/               |          |
# |    episodes         | 116      |
# |    fps              | 1010     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 2305     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0791   |
# |    n_updates        | 76       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 20.1     |
# |    ep_rew_mean      | 20.1     |
# |    exploration_rate | 0.717    |
# | time/               |          |
# |    episodes         | 120      |
# |    fps              | 1010     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 2380     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0393   |
# |    n_updates        | 94       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 19.7     |
# |    ep_rew_mean      | 19.7     |
# |    exploration_rate | 0.711    |
# | time/               |          |
# |    episodes         | 124      |
# |    fps              | 1011     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 2432     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0238   |
# |    n_updates        | 107      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 19.8     |
# |    ep_rew_mean      | 19.8     |
# |    exploration_rate | 0.703    |
# | time/               |          |
# |    episodes         | 128      |
# |    fps              | 886      |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 2504     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0355   |
# |    n_updates        | 125      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 19.3     |
# |    ep_rew_mean      | 19.3     |
# |    exploration_rate | 0.696    |
# | time/               |          |
# |    episodes         | 132      |
# |    fps              | 888      |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 2556     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0184   |
# |    n_updates        | 138      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 19.2     |
# |    ep_rew_mean      | 19.2     |
# |    exploration_rate | 0.688    |
# | time/               |          |
# |    episodes         | 136      |
# |    fps              | 890      |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 2626     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0173   |
# |    n_updates        | 156      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 18.5     |
# |    ep_rew_mean      | 18.5     |
# |    exploration_rate | 0.682    |
# | time/               |          |
# |    episodes         | 140      |
# |    fps              | 892      |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 2674     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00847  |
# |    n_updates        | 168      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 18.3     |
# |    ep_rew_mean      | 18.3     |
# |    exploration_rate | 0.677    |
# | time/               |          |
# |    episodes         | 144      |
# |    fps              | 894      |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 2718     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0161   |
# |    n_updates        | 179      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 18.1     |
# |    ep_rew_mean      | 18.1     |
# |    exploration_rate | 0.671    |
# | time/               |          |
# |    episodes         | 148      |
# |    fps              | 896      |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 2770     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0106   |
# |    n_updates        | 192      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 18       |
# |    ep_rew_mean      | 18       |
# |    exploration_rate | 0.664    |
# | time/               |          |
# |    episodes         | 152      |
# |    fps              | 899      |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 2831     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0166   |
# |    n_updates        | 207      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 17.5     |
# |    ep_rew_mean      | 17.5     |
# |    exploration_rate | 0.656    |
# | time/               |          |
# |    episodes         | 156      |
# |    fps              | 900      |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 2893     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00406  |
# |    n_updates        | 223      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 17.2     |
# |    ep_rew_mean      | 17.2     |
# |    exploration_rate | 0.649    |
# | time/               |          |
# |    episodes         | 160      |
# |    fps              | 903      |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 2959     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00552  |
# |    n_updates        | 239      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 17.5     |
# |    ep_rew_mean      | 17.5     |
# |    exploration_rate | 0.639    |
# | time/               |          |
# |    episodes         | 164      |
# |    fps              | 905      |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 3043     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00422  |
# |    n_updates        | 260      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 17.4     |
# |    ep_rew_mean      | 17.4     |
# |    exploration_rate | 0.632    |
# | time/               |          |
# |    episodes         | 168      |
# |    fps              | 906      |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 3098     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00609  |
# |    n_updates        | 274      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 17.4     |
# |    ep_rew_mean      | 17.4     |
# |    exploration_rate | 0.624    |
# | time/               |          |
# |    episodes         | 172      |
# |    fps              | 908      |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 3164     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00112  |
# |    n_updates        | 290      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 16.8     |
# |    ep_rew_mean      | 16.8     |
# |    exploration_rate | 0.617    |
# | time/               |          |
# |    episodes         | 176      |
# |    fps              | 909      |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 3228     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000575 |
# |    n_updates        | 306      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 16.8     |
# |    ep_rew_mean      | 16.8     |
# |    exploration_rate | 0.61     |
# | time/               |          |
# |    episodes         | 180      |
# |    fps              | 910      |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 3285     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000817 |
# |    n_updates        | 321      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 17       |
# |    ep_rew_mean      | 17       |
# |    exploration_rate | 0.601    |
# | time/               |          |
# |    episodes         | 184      |
# |    fps              | 912      |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 3362     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000632 |
# |    n_updates        | 340      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 16.9     |
# |    ep_rew_mean      | 16.9     |
# |    exploration_rate | 0.595    |
# | time/               |          |
# |    episodes         | 188      |
# |    fps              | 913      |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 3413     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00173  |
# |    n_updates        | 353      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 16.2     |
# |    ep_rew_mean      | 16.2     |
# |    exploration_rate | 0.589    |
# | time/               |          |
# |    episodes         | 192      |
# |    fps              | 914      |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 3464     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00103  |
# |    n_updates        | 365      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 15.7     |
# |    ep_rew_mean      | 15.7     |
# |    exploration_rate | 0.582    |
# | time/               |          |
# |    episodes         | 196      |
# |    fps              | 916      |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 3522     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0011   |
# |    n_updates        | 380      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 15.6     |
# |    ep_rew_mean      | 15.6     |
# |    exploration_rate | 0.576    |
# | time/               |          |
# |    episodes         | 200      |
# |    fps              | 917      |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 3574     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00199  |
# |    n_updates        | 393      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 15.4     |
# |    ep_rew_mean      | 15.4     |
# |    exploration_rate | 0.569    |
# | time/               |          |
# |    episodes         | 204      |
# |    fps              | 918      |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 3627     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00106  |
# |    n_updates        | 406      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 15.3     |
# |    ep_rew_mean      | 15.3     |
# |    exploration_rate | 0.562    |
# | time/               |          |
# |    episodes         | 208      |
# |    fps              | 919      |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 3690     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000565 |
# |    n_updates        | 422      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.9     |
# |    ep_rew_mean      | 14.9     |
# |    exploration_rate | 0.556    |
# | time/               |          |
# |    episodes         | 212      |
# |    fps              | 921      |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 3743     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000807 |
# |    n_updates        | 435      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 15       |
# |    ep_rew_mean      | 15       |
# |    exploration_rate | 0.549    |
# | time/               |          |
# |    episodes         | 216      |
# |    fps              | 881      |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 3801     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00209  |
# |    n_updates        | 450      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.7     |
# |    ep_rew_mean      | 14.7     |
# |    exploration_rate | 0.542    |
# | time/               |          |
# |    episodes         | 220      |
# |    fps              | 855      |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 3854     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000506 |
# |    n_updates        | 463      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.9     |
# |    ep_rew_mean      | 14.9     |
# |    exploration_rate | 0.534    |
# | time/               |          |
# |    episodes         | 224      |
# |    fps              | 857      |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 3925     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00177  |
# |    n_updates        | 481      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.8     |
# |    ep_rew_mean      | 14.8     |
# |    exploration_rate | 0.526    |
# | time/               |          |
# |    episodes         | 228      |
# |    fps              | 859      |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 3988     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0041   |
# |    n_updates        | 496      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.9     |
# |    ep_rew_mean      | 14.9     |
# |    exploration_rate | 0.519    |
# | time/               |          |
# |    episodes         | 232      |
# |    fps              | 859      |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 4051     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.165    |
# |    n_updates        | 512      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.9     |
# |    ep_rew_mean      | 14.9     |
# |    exploration_rate | 0.511    |
# | time/               |          |
# |    episodes         | 236      |
# |    fps              | 862      |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 4119     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0361   |
# |    n_updates        | 529      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 15.2     |
# |    ep_rew_mean      | 15.2     |
# |    exploration_rate | 0.503    |
# | time/               |          |
# |    episodes         | 240      |
# |    fps              | 862      |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 4189     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.
    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 152      |
# |    ep_rew_mean      | 152      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1024     |
# |    fps              | 820      |
# |    time_elapsed     | 91       |
# |    total_timesteps  | 75422    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.936    |
# |    n_updates        | 18355    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 151      |
# |    ep_rew_mean      | 151      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1028     |
# |    fps              | 821      |
# |    time_elapsed     | 92       |
# |    total_timesteps  | 75983    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.822    |
# |    n_updates        | 18495    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 150      |
# |    ep_rew_mean      | 150      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1032     |
# |    fps              | 821      |
# |    time_elapsed     | 93       |
# |    total_timesteps  | 76548    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00264  |
# |    n_updates        | 18636    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 149      |
# |    ep_rew_mean      | 149      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1036     |
# |    fps              | 821      |
# |    time_elapsed     | 93       |
# |    total_timesteps  | 77080    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00363  |
# |    n_updates        | 18769    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 148      |
# |    ep_rew_mean      | 148      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1040     |
# |    fps              | 822      |
# |    time_elapsed     | 94       |
# |    total_timesteps  | 77638    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.836    |
# |    n_updates        | 18909    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 146      |
# |    ep_rew_mean      | 146      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1044     |
# |    fps              | 822      |
# |    time_elapsed     | 95       |
# |    total_timesteps  | 78160    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0233   |
# |    n_updates        | 19039    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 145      |
# |    ep_rew_mean      | 145      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1048     |
# |    fps              | 822      |
# |    time_elapsed     | 95       |
# |    total_timesteps  | 78727    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.855    |
# |    n_updates        | 19181    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 144      |
# |    ep_rew_mean      | 144      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1052     |
# |    fps              | 822      |
# |    time_elapsed     | 96       |
# |    total_timesteps  | 79291    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.865    |
# |    n_updates        | 19322    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 143      |
# |    ep_rew_mean      | 143      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1056     |
# |    fps              | 822      |
# |    time_elapsed     | 97       |
# |    total_timesteps  | 79850    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00461  |
# |    n_updates        | 19462    |
# ----------------------------------
# <video alt="test" autoplay
#                 loop controls style="height: 400px;">
#                 <source src="data:video/mp4;base64,..." type="video/mp4" />
#              </video>

# %% [markdown]
# Посмотрим на то, как проходило обучение:

# %%
from stable_baselines3.common.monitor import load_results

print(load_results("."))
# Out:
#       index      r    l          t
# 0         0   12.0   12   0.376038
# 1         1   20.0   20   0.724613
# 2         2   29.0   29   0.777277
# 3         3   14.0   14   0.778665
# 4         4   11.0   11   0.785391
# ...     ...    ...  ...        ...
# 1052   1052  158.0  158  96.624453
# 1053   1053  144.0  144  96.792609
# 1054   1054  134.0  134  96.951248
# 1055   1055  123.0  123  97.091801
# 1056   1056  149.0  149  97.267467
#
# [1057 rows x 4 columns]

# %% [markdown]
# ### Rllib
#
# <img src="https://docs.ray.io/en/master/_images/rllib-stack.svg" alt="Drawing" style="width: 600px;"/>
#
#
# [RLlib](https://docs.ray.io/en/master/rllib.html) $-$ это open source RL фреймворк, который предлагает высокую масштабируемость и унифицированный API. RLlib изначально поддерживает TensorFlow, TensorFlow Eager и PyTorch. Для распараллеливания используется [Ray Project](https://github.com/ray-project/ray).
#
# **Neural Network Framework:** Tensorflow, PyTorch.
#
# **[Список алгоритмов:](https://docs.ray.io/en/master/rllib-algorithms.html)** A2C, A3C, ARS, BC, ES, DDPG, TD3, APEX-DDPG, Dreamer, DQN, Rainbow, APEX-DQN, IMPALA, MAML, MARWIL, MBMPO, PG, PPO, APPO, SAC, LinUCB, LinTS, AlphaZero, QMIX, MADDPG

# %%
# if COLAB:
if True:
    # !pip install ray[rllib]==1.2.0 gym==0.17.3
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting ray[rllib]==1.2.0
#   Downloading ray-1.2.0-cp37-cp37m-manylinux2014_x86_64.whl (47.5 MB)
#      |████████████████████████████████| 47.5 MB 1.3 MB/s
# Collecting gym==0.17.3
#   Downloading gym-0.17.3.tar.gz (1.6 MB)
#      |████████████████████████████████| 1.6 MB 56.5 MB/s
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from gym==0.17.3) (1.4.1)
# Requirement already satisfied: numpy>=1.10.4 in /usr/local/lib/python3.7/dist-packages (from gym==0.17.3) (1.21.6)
# Requirement already satisfied: pyglet<=1.5.0,>=1.4.0 in /usr/local/lib/python3.7/dist-packages (from gym==0.17.3) (1.5.0)
# Requirement already satisfied: cloudpickle<1.7.0,>=1.2.0 in /usr/local/lib/python3.7/dist-packages (from gym==0.17.3) (1.3.0)
# Collecting aiohttp
#   Downloading aiohttp-3.8.1-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (1.1 MB)
#      |████████████████████████████████| 1.1 MB 57.8 MB/s
# Collecting opencensus
#   Downloading opencensus-0.9.0-py2.py3-none-any.whl (128 kB)
#      |████████████████████████████████| 128 kB 59.4 MB/s
# Collecting redis>=3.5.0
#   Downloading redis-4.3.3-py3-none-any.whl (244 kB)
#      |████████████████████████████████| 244 kB 73.9 MB/s
# Requirement already satisfied: jsonschema in /usr/local/lib/python3.7/dist-packages (from ray[rllib]==1.2.0) (4.3.3)
# Collecting py-spy>=0.2.0
#   Downloading py_spy-0.3.12-py2.py3-none-manylinux_2_5_x86_64.manylinux1_x86_64.whl (3.1 MB)
#      |████████████████████████████████| 3.1 MB 50.1 MB/s
# Requirement already satisfied: protobuf>=3.8.0 in /usr/local/lib/python3.7/dist-packages (from ray[rllib]==1.2.0) (3.17.3)
# Collecting gpustat
#   Downloading gpustat-0.6.0.tar.gz (78 kB)
#      |████████████████████████████████| 78 kB 6.7 MB/s
# Requirement already satisfied: msgpack<2.0.0,>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from ray[rllib]==1.2.0) (1.0.3)
# Collecting aiohttp-cors
#   Downloading aiohttp_cors-0.7.0-py3-none-any.whl (27 kB)
# Requirement already satisfied: click>=7.0 in /usr/local/lib/python3.7/dist-packages (from ray[rllib]==1.2.0) (7.1.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from ray[rllib]==1.2.0) (2.23.0)
# Collecting colorama
#   Downloading colorama-0.4.4-py2.py3-none-any.whl (16 kB)
# Requirement already satisfied: prometheus-client>=0.7.1 in /usr/local/lib/python3.7/dist-packages (from ray[rllib]==1.2.0) (0.14.1)
# Collecting aioredis
#   Downloading aioredis-2.0.1-py3-none-any.whl (71 kB)
#      |████████████████████████████████| 71 kB 10.5 MB/s
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.7/dist-packages (from ray[rllib]==1.2.0) (3.13)
# Requirement already satisfied: grpcio>=1.28.1 in /usr/local/lib/python3.7/dist-packages (from ray[rllib]==1.2.0) (1.46.3)
# Collecting colorful
#   Downloading colorful-0.5.4-py2.py3-none-any.whl (201 kB)
#      |████████████████████████████████| 201 kB 71.7 MB/s
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from ray[rllib]==1.2.0) (3.7.0)
# Collecting tensorboardX
#   Downloading tensorboardX-2.5.1-py2.py3-none-any.whl (125 kB)
#      |████████████████████████████████| 125 kB 68.6 MB/s
# Requirement already satisfied: atari-py in /usr/local/lib/python3.7/dist-packages (from ray[rllib]==1.2.0) (0.2.9)
# Requirement already satisfied: gym[atari] in /usr/local/lib/python3.7/dist-packages (from ray[rllib]==1.2.0) (0.21.0)
# Collecting lz4
#   Downloading lz4-4.0.1-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.2 MB)
#      |████████████████████████████████| 1.2 MB 61.0 MB/s
# Requirement already satisfied: dm-tree in /usr/local/lib/python3.7/dist-packages (from ray[rllib]==1.2.0) (0.1.7)
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from ray[rllib]==1.2.0) (1.3.5)
# Collecting opencv-python-headless<=4.3.0.36
#   Downloading opencv_python_headless-4.2.0.34-cp37-cp37m-manylinux1_x86_64.whl (21.6 MB)
#      |████████████████████████████████| 21.6 MB 1.2 MB/s
# Requirement already satisfied: tabulate in /usr/local/lib/python3.7/dist-packages (from ray[rllib]==1.2.0) (0.8.9)
# Requirement already satisfied: six>=1.5.2 in /usr/local/lib/python3.7/dist-packages (from grpcio>=1.28.1->ray[rllib]==1.2.0) (1.15.0)
# Requirement already satisfied: future in /usr/local/lib/python3.7/dist-packages (from pyglet<=1.5.0,>=1.4.0->gym==0.17.3) (0.16.0)
# Requirement already satisfied: importlib-metadata>=1.0 in /usr/local/lib/python3.7/dist-packages (from redis>=3.5.0->ray[rllib]==1.2.0) (4.11.4)
# Requirement already satisfied: packaging>=20.4 in /usr/local/lib/python3.7/dist-packages (from redis>=3.5.0->ray[rllib]==1.2.0) (21.3)
# Collecting deprecated>=1.2.3
#   Downloading Deprecated-1.2.13-py2.py3-none-any.whl (9.6 kB)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from redis>=3.5.0->ray[rllib]==1.2.0) (4.2.0)
# Collecting async-timeout>=4.0.2
#   Downloading async_timeout-4.0.2-py3-none-any.whl (5.8 kB)
# Requirement already satisfied: wrapt<2,>=1.10 in /usr/local/lib/python3.7/dist-packages (from deprecated>=1.2.3->redis>=3.5.0->ray[rllib]==1.2.0) (1.14.1)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=1.0->redis>=3.5.0->ray[rllib]==1.2.0) (3.8.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.4->redis>=3.5.0->ray[rllib]==1.2.0) (3.0.9)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->ray[rllib]==1.2.0) (21.4.0)
# Collecting multidict<7.0,>=4.5
#   Downloading multidict-6.0.2-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (94 kB)
#      |████████████████████████████████| 94 kB 4.1 MB/s
# Collecting asynctest==0.13.0
#   Downloading asynctest-0.13.0-py3-none-any.whl (26 kB)
# Requirement already satisfied: charset-normalizer<3.0,>=2.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->ray[rllib]==1.2.0) (2.0.12)
# Collecting frozenlist>=1.1.1
#   Downloading frozenlist-1.3.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (144 kB)
#      |████████████████████████████████| 144 kB 74.8 MB/s
# Collecting yarl<2.0,>=1.0
#   Downloading yarl-1.7.2-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (271 kB)
#      |████████████████████████████████| 271 kB 71.7 MB/s
# Collecting aiosignal>=1.1.2
#   Downloading aiosignal-1.2.0-py3-none-any.whl (8.2 kB)
# Requirement already satisfied: idna>=2.0 in /usr/local/lib/python3.7/dist-packages (from yarl<2.0,>=1.0->aiohttp->ray[rllib]==1.2.0) (2.10)
# Requirement already satisfied: nvidia-ml-py3>=7.352.0 in /usr/local/lib/python3.7/dist-packages (from gpustat->ray[rllib]==1.2.0) (7.352.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.7/dist-packages (from gpustat->ray[rllib]==1.2.0) (5.4.8)
# Collecting blessings>=1.6
#   Downloading blessings-1.7-py3-none-any.whl (18 kB)
# Collecting gym[atari]
#   Downloading gym-0.24.0.tar.gz (694 kB)
#      |████████████████████████████████| 694 kB 55.5 MB/s
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
#   Downloading gym-0.23.1.tar.gz (626 kB)
#      |████████████████████████████████| 626 kB 62.3 MB/s
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
#   Downloading gym-0.23.0.tar.gz (624 kB)
#      |████████████████████████████████| 624 kB 62.5 MB/s
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
#   Downloading gym-0.22.0.tar.gz (631 kB)
#      |████████████████████████████████| 631 kB 57.8 MB/s
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
#   Downloading gym-0.20.0.tar.gz (1.6 MB)
#      |████████████████████████████████| 1.6 MB 53.6 MB/s
#   Downloading gym-0.19.0.tar.gz (1.6 MB)
#      |████████████████████████████████| 1.6 MB 53.1 MB/s
#   Downloading gym-0.18.3.tar.gz (1.6 MB)
#      |████████████████████████████████| 1.6 MB 50.3 MB/s
#   Downloading gym-0.18.0.tar.gz (1.6 MB)
#      |████████████████████████████████| 1.6 MB 27.8 MB/s
# Requirement already satisfied: Pillow in /usr/local/lib/python3.7/dist-packages (from gym==0.17.3) (7.1.2)
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.7/dist-packages (from gym==0.17.3) (4.1.2.30)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /usr/local/lib/python3.7/dist-packages (from jsonschema->ray[rllib]==1.2.0) (0.18.1)
# Requirement already satisfied: importlib-resources>=1.4.0 in /usr/local/lib/python3.7/dist-packages (from jsonschema->ray[rllib]==1.2.0) (5.7.1)
# Collecting opencensus-context>=0.1.2
#   Downloading opencensus_context-0.1.2-py2.py3-none-any.whl (4.4 kB)
# Requirement already satisfied: google-api-core<3.0.0,>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from opencensus->ray[rllib]==1.2.0) (1.31.6)
# Requirement already satisfied: setuptools>=40.3.0 in /usr/local/lib/python3.7/dist-packages (from google-api-core<3.0.0,>=1.0.0->opencensus->ray[rllib]==1.2.0) (57.4.0)
# Requirement already satisfied: pytz in /usr/local/lib/python3.7/dist-packages (from google-api-core<3.0.0,>=1.0.0->opencensus->ray[rllib]==1.2.0) (2022.1)
# Requirement already satisfied: google-auth<2.0dev,>=1.25.0 in /usr/local/lib/python3.7/dist-packages (from google-api-core<3.0.0,>=1.0.0->opencensus->ray[rllib]==1.2.0) (1.35.0)
# Requirement already satisfied: googleapis-common-protos<2.0dev,>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from google-api-core<3.0.0,>=1.0.0->opencensus->ray[rllib]==1.2.0) (1.56.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.7/dist-packages (from google-auth<2.0dev,>=1.25.0->google-api-core<3.0.0,>=1.0.0->opencensus->ray[rllib]==1.2.0) (4.8)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from google-auth<2.0dev,>=1.25.0->google-api-core<3.0.0,>=1.0.0->opencensus->ray[rllib]==1.2.0) (4.2.4)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from google-auth<2.0dev,>=1.25.0->google-api-core<3.0.0,>=1.0.0->opencensus->ray[rllib]==1.2.0) (0.2.8)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.7/dist-packages (from pyasn1-modules>=0.2.1->google-auth<2.0dev,>=1.25.0->google-api-core<3.0.0,>=1.0.0->opencensus->ray[rllib]==1.2.0) (0.4.8)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->ray[rllib]==1.2.0) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->ray[rllib]==1.2.0) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->ray[rllib]==1.2.0) (2022.5.18.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas->ray[rllib]==1.2.0) (2.8.2)
# Building wheels for collected packages: gym, gpustat
#   Building wheel for gym (setup.py) ... done
#   Created wheel for gym: filename=gym-0.17.3-py3-none-any.whl size=1654653 sha256=b3a64962b9b69ecbcc0fd2e8a090b5ed4a409d48d894ea4556c58a327f425381
#   Stored in directory: /root/.cache/pip/wheels/d1/81/4b/dd9c029691022cb957398d1f015e66b75e37637dda61abdf58
#   Building wheel for gpustat (setup.py) ... done
#   Created wheel for gpustat: filename=gpustat-0.6.0-py3-none-any.whl size=12617 sha256=d262ccae6aa7ac8ef371b746610ca16b2b8b8125e83ac5e0da58a9dc42477f36
#   Stored in directory: /root/.cache/pip/wheels/e6/67/af/f1ad15974b8fd95f59a63dbf854483ebe5c7a46a93930798b8
# Successfully built gym gpustat
# Installing collected packages: multidict, frozenlist, yarl, asynctest, async-timeout, aiosignal, opencensus-context, deprecated, blessings, aiohttp, redis, py-spy, opencensus, gym, gpustat, colorful, colorama, aioredis, aiohttp-cors, tensorboardX, ray, opencv-python-headless, lz4
#   Attempting uninstall: gym
#     Found existing installation: gym 0.21.0
#     Uninstalling gym-0.21.0:
#       Successfully uninstalled gym-0.21.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# stable-baselines3 1.5.0 requires gym==0.21, but you have gym 0.17.3 which is incompatible.
# Successfully installed aiohttp-3.8.1 aiohttp-cors-0.7.0 aioredis-2.0.1 aiosignal-1.2.0 async-timeout-4.0.2 asynctest-0.13.0 blessings-1.7 colorama-0.4.4 colorful-0.5.4 deprecated-1.2.13 frozenlist-1.3.0 gpustat-0.6.0 gym-0.17.3 lz4-4.0.1 multidict-6.0.2 opencensus-0.9.0 opencensus-context-0.1.2 opencv-python-headless-4.2.0.34 py-spy-0.3.12 ray-1.2.0 redis-4.3.3 tensorboardX-2.5.1 yarl-1.7.2

# %%
import gym
gym.__version__
# Out:
# '0.17.3'

# %%
import ray

ray.init(num_cpus=2, ignore_reinit_error=True, log_to_driver=False)
# Out:
# 2022-06-06 18:14:19,060	INFO services.py:1174 -- View the Ray dashboard at http://127.0.0.1:8265
# {'metrics_export_port': 61890,
#  'node_id': 'b80b24182ac0841eebfd5762a973c2fa72e706b1a323745c50de7e81',
#  'node_ip_address': '172.28.0.2',
#  'object_store_address': '/tmp/ray/session_2022-06-06_18-14-18_388620_1336/sockets/plasma_store',
#  'raylet_ip_address': '172.28.0.2',
#  'raylet_socket_name': '/tmp/ray/session_2022-06-06_18-14-18_388620_1336/sockets/raylet',
#  'redis_address': '172.28.0.2:6379',
#  'session_dir': '/tmp/ray/session_2022-06-06_18-14-18_388620_1336',
#  'webui_url': '127.0.0.1:8265'}

# %%
from ray.rllib.agents.dqn import DQNTrainer
from ray.tune import tune
import torch

def env_creator(env_config):
    pass

config = {"env": "CartPole-v0", "num_workers": 1, "monitor": True}

if torch.cuda.is_available():
    config['num_gpus'] = 1

results = tune.run("DQN",
                   config = config,
                   verbose=True,
                   stop={"timesteps_total": 10 ** 4},
                   checkpoint_freq=10)
# Out:
# == Status ==<br>Memory usage on this node: 3.3/12.7 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 0/2 CPUs, 0/1 GPUs, 0.0/7.18 GiB heap, 0.0/2.44 GiB objects (0/1.0 accelerator_type:T4)<br>Result logdir: /root/ray_results/DQN<br>Number of trials: 1/1 (1 ERROR)<br>Number of errored trials: 1<br><table>
# <thead>
# <tr><th>Trial name                 </th><th style="text-align: right;">  # failures</th><th>error file                                                                       </th></tr>
# </thead>
# <tbody>
# <tr><td>DQN_CartPole-v0_c35f0_00000</td><td style="text-align: right;">           1</td><td>/root/ray_results/DQN/DQN_CartPole-v0_c35f0_00000_0_2022-06-06_18-16-19/error.txt</td></tr>
# </tbody>
# </table><br>
# ---------------------------------------------------------------------------
# TuneError                                 Traceback (most recent call last)
# <ipython-input-3-b8b786a0622e> in <module>()
#      15                    verbose=True,
#      16                    stop={"timesteps_total": 10 ** 4},
# ---> 17                    checkpoint_freq=10)
#
# /usr/local/lib/python3.7/dist-packages/ray/tune/tune.py in run(run_or_experiment, name, metric, mode, stop, time_budget_s, config, resources_per_trial, num_samples, local_dir, search_alg, scheduler, keep_checkpoints_num, checkpoint_score_attr, checkpoint_freq, checkpoint_at_end, verbose, progress_reporter, log_to_file, trial_name_creator, trial_dirname_creator, sync_config, export_formats, max_failures, fail_fast, restore, server_port, resume, queue_trials, reuse_actors, trial_executor, raise_on_failed_trial, callbacks, loggers, ray_auto_init, run_errored_only, global_checkpoint_period, with_server, upload_dir, sync_to_cloud, sync_to_driver, sync_on_checkpoint)
#     442     if incomplete_trials:
#     443         if raise_on_failed_trial:
# --> 444             raise TuneError("Trials did not complete", incomplete_trials)
#     445         else:
#     446             logger.error("Trials did not complete: %s", incomplete_trials)
#
# TuneError: ('Trials did not complete', [DQN_CartPole-v0_c35f0_00000])

# %%
run_folder = results.trials[0].logdir
show_video(folder=run_folder)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-f8cf619b23a7> in <module>()
# ----> 1 run_folder = results.trials[0].logdir
#       2 show_video(folder=run_folder)
#
# NameError: name 'results' is not defined

# %% [markdown]
# Загружаем сохраненные веса:

# %%
policy = DQNTrainer(env="CartPole-v0", config=config)
policy.restore(run_folder + '/checkpoint_10/checkpoint-10')
# Out:
# 2021-03-22 18:10:46,919	INFO trainer.py:616 -- Tip: set framework=tfe or the --eager flag to enable TensorFlow eager execution
# 2021-03-22 18:10:46,920	INFO trainer.py:643 -- Current log_level is WARN. For more information, set 'log_level': 'INFO' / 'DEBUG' or use the -v and -vv flags.
# 2021-03-22 18:10:52,616	WARNING deprecation.py:34 -- DeprecationWarning: `framestack` has been deprecated. Use `num_framestacks (int)` instead. This will raise an error in the future!
# 2021-03-22 18:10:52,800	WARNING deprecation.py:34 -- DeprecationWarning: `framestack` has been deprecated. Use `num_framestacks (int)` instead. This will raise an error in the future!
# 2021-03-22 18:10:54,140	WARNING util.py:47 -- Install gputil for GPU system monitoring.
# 2021-03-22 18:10:54,236	INFO trainable.py:372 -- Restored on 172.28.0.2 from checkpoint: /root/ray_results/DQN/DQN_CartPole-v0_82784_00000_0_2021-03-22_18-07-48/checkpoint_10/checkpoint-10
# 2021-03-22 18:10:54,237	INFO trainable.py:379 -- Current state after restoring: {'_iteration': 10, '_timesteps_total': None, '_time_total': 58.45544219017029, '_episodes_total': 245}

# %%
env = gym.make('CartPole-v0')
env = gym.wrappers.Monitor(env, directory="./video", force=True)

obs = env.reset() 
done = False
while not done:
    obs, reward, done, _ = env.step(policy.compute_action(obs)) 
env.close()

show_video()
# Out:
# <video alt="test" autoplay
#                 loop controls style="height: 400px;">
#                 <source src="data:video/mp4;base64,..." type="video/mp4" />
#              </video>

# %% [markdown]
# ### PFRL
#
# <img src="https://raw.githubusercontent.com/pfnet/pfrl/master/assets/PFRL.png" alt="Drawing" style="width: 180px;"/>
#
#
# PFRL $-$ это библиотека глубокого обучения с подкреплением, которая реализует различные современные алгоритмы на Python, с использованием PyTorch. Бывший ChainerRL.
#
# **Neural Network Framework:** PyTorch.
#
# **Список алгоритмов:** DQN, Rainbow, IQN, DDPG, A3C, ACER, PPO, TRPO, TD3, SAC
#
# Быстрый старт: [quickstart.ipynb](https://github.com/pfnet/pfrl/blob/master/examples/quickstart/quickstart.ipynb)
#
# Примеры: [examples](https://github.com/pfnet/pfrl/tree/master/examples)

# %% [markdown]
# ### Заслуживают упоминания:
#
# * [OpenAI Spinning Up RL](https://github.com/openai/spinningup)
# * [LeelaChessZero](https://github.com/LeelaChessZero)
# * [Tianshou](https://github.com/thu-ml/tianshou)
# * [TF agents](https://github.com/tensorflow/agents)
# * [Catalyst-rl](https://github.com/catalyst-team/catalyst-rl)
# * [Dopamine](https://github.com/google/dopamine)
# * [TRFL](https://github.com/deepmind/trfl)
# * [Keras RL](https://github.com/keras-rl/keras-rl)
# * [PyTorch-RL](https://github.com/Khrylx/PyTorch-RL)
# * [PyMarl](https://github.com/oxwhirl/pymarl)
# * [Denny Britz RL](https://github.com/dennybritz/reinforcement-learning)
# * [DeepRL-Tutorials](https://github.com/qfettes/DeepRL-Tutorials)
# * [RL Adventure](https://github.com/higgsfield/RL-Adventure)
# * [FacebookResearch ELF](https://github.com/facebookresearch/ELF)
# * [SLM-Lab](https://github.com/kengz/SLM-Lab)

# %% [markdown]
# ## 3. Experiments monitoring. Weights & Biases.
# Несколько примеров: [Dexterity](https://wandb.ai/openai/published-work/Learning-Dexterity-End-to-End--VmlldzoxMTUyMDQ), [RL Example: Pacman](https://wandb.ai/yashkotadia/rl-example).
#
# Для того, чтобы результаты записывались в облако, нужно залогиниться. Предоставить свой api-key. Самый простой способ - использование консоли:

# %%
if COLAB:
    # !pip install wandb --quiet

import wandb
wandb.login()
# Out:
#      |████████████████████████████████| 1.8MB 5.6MB/s
#      |████████████████████████████████| 102kB 8.7MB/s
#      |████████████████████████████████| 163kB 23.7MB/s
#      |████████████████████████████████| 133kB 23.0MB/s
#      |████████████████████████████████| 102kB 7.6MB/s
#      |████████████████████████████████| 71kB 6.2MB/s
#   Building wheel for watchdog (setup.py) ... done
#   Building wheel for subprocess32 (setup.py) ... done
#   Building wheel for pathtools (setup.py) ... done
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# True

# %%
import math
import random

# Start a new run, tracking hyperparameters in config
wandb.init(project="test-drive", config={
    "learning_rate": 0.01,
    "dropout": 0.2,
    "architecture": "CNN",
    "dataset": "CIFAR-100",
})
config = wandb.config

# Simulating a training or evaluation loop
for x in range(50):
    acc = math.log(1 + x + random.random()*config.learning_rate) + random.random() + config.dropout
    loss = 10 - math.log(1 + x + random.random() + config.learning_rate*x) + random.random() + config.dropout
    # Log metrics from your script to W&B
    wandb.log({"acc":acc, "loss":loss})
# Out:
# wandb: Currently logged in as: tviskaron (use `wandb login --relogin` to force relogin)
#                 Tracking run with wandb version 0.10.11<br/>
#                 Syncing run <strong style="color:#cdcd00">rare-bee-7</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/tviskaron/test-drive" target="_blank">https://wandb.ai/tviskaron/test-drive</a><br/>
#                 Run page: <a href="https://wandb.ai/tviskaron/test-drive/runs/6ffuichs" target="_blank">https://wandb.ai/tviskaron/test-drive/runs/6ffuichs</a><br/>
#                 Run data is saved locally in <code>/content/wandb/run-20201123_182610-6ffuichs</code><br/><br/>
